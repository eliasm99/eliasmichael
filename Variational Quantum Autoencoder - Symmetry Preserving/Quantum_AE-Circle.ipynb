# %% [markdown]
# # Quantum AE Notebook - Elias Michael

# %% [markdown]
# ## Variational Quantum AutoEncoder

# %% [markdown]
# ### Import Libraries

# %%
import pennylane as qml
import jax
import jax.numpy as jnp
import numpy as np
import optax
from jax import jit, value_and_grad, vmap
import matplotlib.pyplot as plt

# %%
# JAX command for further accuracy
jax.config.update("jax_enable_x64", True)

# %%
def expressive_block_circuit5(x, weights, wires, 
                               reupload=True, 
                               alternate_embedding=True):
    n_layers = weights.shape[0]  # e.g., 2 or 3
    n_wires = len(wires)
    index = sorted(list(range(len(x))) * (n_wires // len(x) + 1))

    def embed_inputs(layer):
        for idx, wire in enumerate(wires):
            if not alternate_embedding:
                gate = qml.RY
            else:
                # Alternate embedding gates per layer
                if layer % 2 == 0:
                    gate = [qml.RY, qml.RX, qml.RY][idx % 3]
                else:
                    gate = [qml.RX, qml.RY, qml.RX][idx % 3]
            gate(x[index[idx]], wires=wire)

    for l in range(n_layers):
        if l == 0 or reupload:
            embed_inputs(l)

        # --- Initial RX + RZ rotations (as in Circuit 5) ---
        for i, wire in enumerate(wires):
            qml.RX(weights[l, i, 0], wires=wire)
            qml.RZ(weights[l, i, 1], wires=wire)

        # --- Staircase entanglement with interleaved RZ gates ---
        for i in range(n_wires - 1):
            # Optional mid-layer RZs (imitating interleaved ones in Circuit 5)
            qml.RZ(weights[l, i, 2], wires=wires[i])
            qml.CNOT(wires=[wires[i], wires[i + 1]])

        # Add final RZ gates on remaining qubits to match diagram
        qml.RZ(weights[l, n_wires - 1, 2], wires=wires[n_wires - 1])

        # --- Final RX + RZ again (as in last part of Circuit 5) ---
        for i, wire in enumerate(wires):
            qml.RX(weights[l, i, 3], wires=wire)
            qml.RZ(weights[l, i, 4], wires=wire)

# %%
import pennylane as qml
import jax.numpy as jnp
import jax

# Dummy values
n_layers = 2
n_wires = 8
x = jnp.array([1.0, 1.2, 1.5])
weights = jnp.ones((n_layers, n_wires, 5))
wires = list(range(n_wires))

dev = qml.device("default.qubit", wires=n_wires)

@qml.qnode(dev)
def circuit():
    expressive_block_circuit5(x, weights, wires, 
                     reupload=True, 
                     alternate_embedding=True)
    return qml.state()

# %%
qml.drawer.draw_mpl(circuit)()
# Out:
# (<Figure size 3100x900 with 1 Axes>, <Axes: >)

# %% [markdown]
# ### Defining the Qubit Setup

# %%
n_qubits = 4
latent_wire = 0 # First input of the encoder / Holds all the compressed info after training (encoder)
trash_wire = 1 # Second input of the encoder / Discarded (Traced out) after training
reference_wire = 2 # Used to compare with trash qubit after encoder, then used as a fresh qubit for the decoder input
ancilla_wire = 3 # For measuring the similarity in SWAP test
dev = qml.device("default.qubit.jax", wires=n_qubits)

# %% [markdown]
# ### Data Generation

# %%
# Centering the circle in the reversible domain (0, pi)
ds = (jnp.pi - 2)/2

# %%
def generate_circle_dataset(n_samples=1000, seed=0, angle_range=(0, 2*jnp.pi)):
    key = jax.random.PRNGKey(seed)
    angles = jax.random.uniform(key, shape=(n_samples,), minval=angle_range[0], maxval=angle_range[1])
    data = jnp.stack([jnp.cos(angles)+1+ds, jnp.sin(angles)+1+ds], axis=1) # Shifting our circle within the range 0 to pi -> x0,x1 ∈ [ds,ds+2] to avoid ambiguity
    return data, angles

# %% [markdown]
# ### Encoder Layer (Angle embedding & Re-Uploading & Alternate Embedding)

# %%
def expressive_block(x, weights, wires, rot=[qml.RY, qml.RZ, qml.RX], reupload=True, alternate_embedding=True):
    n_layers = weights.shape[0]
    n_wires = len(wires)
    index = sorted(list(range(len(x))) * (n_wires // len(x) + 1))

    def embed_inputs():
        for idx, wire in enumerate(wires):
            gate = qml.RY if not alternate_embedding else [qml.RY, qml.RX][idx % 2]
            gate(x[index[idx]], wires=wire)

    for l in range(n_layers):
        if l == 0 or reupload:
            embed_inputs()
        for i, wire in enumerate(wires):
            for j, gate in enumerate(rot):
                gate(weights[l, i, j], wires=wire)
        for i in range(n_wires):
            qml.CNOT(wires=[wires[i], wires[(i + 1) % n_wires]])

# %% [markdown]
# ### Decoding Layer (Inverse Operators - Mirroring Encoder)

# %%
def expressive_block_adjoint(x, weights, wires, rot=[qml.RY, qml.RZ, qml.RX], reupload=True, alternate_embedding=True):
    n_layers = weights.shape[0]
    n_wires = len(wires)
    index = sorted(list(range(len(x))) * (n_wires // len(x) + 1))

    def embed_inputs():
        for idx, wire in enumerate(wires):
            gate = qml.RY if not alternate_embedding else [qml.RY, qml.RX][idx % 2]
            qml.adjoint(gate)(x[index[idx]], wires=wire)

    for l in reversed(range(n_layers)):
        # Reverse entanglement
        for i in reversed(range(n_wires)):
            qml.adjoint(qml.CNOT)(wires=[wires[i], wires[(i + 1) % n_wires]])

        # Reverse parameterized rotations
        for i in reversed(range(n_wires)):
            for j in reversed(range(len(rot))):
                qml.adjoint(rot[j])(weights[l, i, j], wires=wires[i])

        # Reverse data reuploading (if applied before this layer)
        if l == 0 or reupload:
            embed_inputs()

# %% [markdown]
# ### SWAP Test (Loss Function Measurement)

# %% [markdown]
# In the SWAP Test we train only for the encoder parameters, since for the decoder we will just apply the inverse of all the encoder layers

# %%
@qml.qnode(dev, interface="jax")
def swap_test_circuit(params, x):
    # Prepare reference state
    qml.RX(x[0], wires=latent_wire)
    qml.RX(x[1], wires=trash_wire)

    # Encode data
    expressive_block(
        x=x,
        weights=params,
        wires=[latent_wire, trash_wire],
        rot=[qml.RY, qml.RZ, qml.RX],
        reupload=True,
        alternate_embedding=True
    )

    # SWAP test
    qml.Hadamard(wires=ancilla_wire)
    qml.CSWAP(wires=[ancilla_wire, trash_wire, reference_wire])
    qml.Hadamard(wires=ancilla_wire)

    return qml.expval(qml.PauliZ(ancilla_wire))

# %% [markdown]
# #### Batched Loss Function

# %%
def swap_test_loss(params, batch):
    def single_sample_loss(x):
        ancilla_z = swap_test_circuit(params, x)
        return 1.0 - ancilla_z  
    batched_loss = vmap(single_sample_loss)(batch)
    return jnp.mean(batched_loss)

# %%
# JAX Speed Optimizer
loss_fn = jit(swap_test_loss)

# %% [markdown]
# ### Parameters Initialization

# %%
def init_encoder_params(n_layers=20, n_wires=2, n_rot=3, seed=0):
    key = jax.random.PRNGKey(seed)
    return jax.random.uniform(
        key, shape=(n_layers, n_wires, n_rot), minval=-1, maxval=1
    )

# %%
# Initialize weights
n_layers, n_wires, n_rot = 20, 2, 3
params = init_encoder_params(n_layers, n_wires, n_rot)

# %% [markdown]
# ### Training Data

# %%
# Generating the dataset
data, _ = generate_circle_dataset(n_samples=1000, seed=42)

# --- Shuffle uniformly
rng = np.random.default_rng(42)
indices = np.arange(len(data))
rng.shuffle(indices)

# --- Select stratified validation set (even angle spacing)
val_size = int(0.2 * len(data))
val_indices = np.linspace(0, len(data) - 1, num=val_size, dtype=int)
val_indices = indices[val_indices]

# --- Remaining indices for training
train_indices = np.setdiff1d(indices, val_indices)

# --- Final splits
train_data = data[train_indices]
val_data = data[val_indices]

# %% [markdown]
# ### Learning Rate & Optimizer Scheduler Setup

# %%
# Learning rate scheduler setup
initial_lr = 0.1
decay_rate = 0.8
decay_steps = 1000  # decay every 1000 steps

schedule = optax.exponential_decay(
    init_value=initial_lr,
    transition_steps=decay_steps,
    decay_rate=decay_rate,
    staircase=True
)

# %%
# Optimizer with schedule
optimizer = optax.adam(learning_rate=schedule)
opt_state = optimizer.init(params)

# %% [markdown]
# ### Training Loop

# %%
# Training Parameters
batch_size = 64
epochs = 30000

# %%
# JAX Speed Optimizer
loss_grad_fn = jit(value_and_grad(swap_test_loss))

# Logging Arrays
loss_history = []
val_loss_history = []
grad_norm_history = []
lr_history = []

# %%
# Early stopping setup 
best_val_loss = float("inf")
patience = 50
epochs_without_improvement = 0

# %%
# Training loop
for epoch in range(epochs):
    # Sample random training batch
    batch_idx = np.random.choice(train_data.shape[0], batch_size, replace=False)
    batch = train_data[batch_idx]

    # Compute training loss and gradients
    loss_val, grads = loss_grad_fn(params, batch)

    # Compute gradient norm
    flat_grads, _ = jax.flatten_util.ravel_pytree(grads)
    grad_norm = jnp.linalg.norm(flat_grads)

    # Update step
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)

    # Track metrics
    loss_history.append(loss_val)
    grad_norm_history.append(grad_norm)
    lr_history.append(schedule(epoch))

    # --- Validation ---
    if epoch % 100 == 0 or epoch == epochs - 1:
        val_loss = swap_test_loss(params, val_data)
        val_loss_history.append(val_loss)

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1

        # Logging
        print(f"Epoch {epoch:5d} | Train Loss: {loss_val:.8f} | Val Loss: {val_loss:.8f} | Grad Norm: {grad_norm:.4e} | LR: {lr_history[-1]:.6f}")

        # Stop if no improvement
        if epochs_without_improvement >= patience:
            print(f"\n⏹️ Early stopping at epoch {epoch} (val loss stagnated for {patience} steps)")
            break
# Out:
# Epoch     0 | Train Loss: 0.42917434 | Val Loss: 0.43984381 | Grad Norm: 7.4290e-01 | LR: 0.100000
# Epoch   100 | Train Loss: 0.00093806 | Val Loss: 0.00086265 | Grad Norm: 5.4338e-02 | LR: 0.100000
# Epoch   200 | Train Loss: 0.00053003 | Val Loss: 0.00158847 | Grad Norm: 4.0680e-02 | LR: 0.100000
# Epoch   300 | Train Loss: 0.00077182 | Val Loss: 0.00060819 | Grad Norm: 7.3152e-02 | LR: 0.100000
# Epoch   400 | Train Loss: 0.00160052 | Val Loss: 0.00195831 | Grad Norm: 8.6041e-02 | LR: 0.100000
# Epoch   500 | Train Loss: 0.00078516 | Val Loss: 0.00206557 | Grad Norm: 6.1827e-02 | LR: 0.100000
# Epoch   600 | Train Loss: 0.00044509 | Val Loss: 0.00082880 | Grad Norm: 4.3976e-02 | LR: 0.100000
# Epoch   700 | Train Loss: 0.00465917 | Val Loss: 0.00506024 | Grad Norm: 1.6242e-01 | LR: 0.100000
# Epoch   800 | Train Loss: 0.00571855 | Val Loss: 0.00852266 | Grad Norm: 1.5532e-01 | LR: 0.100000
# Epoch   900 | Train Loss: 0.00040343 | Val Loss: 0.00020201 | Grad Norm: 5.0177e-02 | LR: 0.100000
# Epoch  1000 | Train Loss: 0.00009964 | Val Loss: 0.00007709 | Grad Norm: 1.6406e-02 | LR: 0.080000
# Epoch  1100 | Train Loss: 0.00008924 | Val Loss: 0.00008551 | Grad Norm: 1.7642e-02 | LR: 0.080000
# Epoch  1200 | Train Loss: 0.00014645 | Val Loss: 0.00007353 | Grad Norm: 2.8134e-02 | LR: 0.080000
# Epoch  1300 | Train Loss: 0.00005838 | Val Loss: 0.00008183 | Grad Norm: 1.1691e-02 | LR: 0.080000
# Epoch  1400 | Train Loss: 0.00005415 | Val Loss: 0.00007720 | Grad Norm: 8.5059e-03 | LR: 0.080000
# Epoch  1500 | Train Loss: 0.00035962 | Val Loss: 0.00045452 | Grad Norm: 4.7806e-02 | LR: 0.080000
# Epoch  1600 | Train Loss: 0.00065781 | Val Loss: 0.00104186 | Grad Norm: 7.0179e-02 | LR: 0.080000
# Epoch  1700 | Train Loss: 0.00228787 | Val Loss: 0.00138408 | Grad Norm: 1.1776e-01 | LR: 0.080000
# Epoch  1800 | Train Loss: 0.00183013 | Val Loss: 0.00126721 | Grad Norm: 7.7115e-02 | LR: 0.080000
# Epoch  1900 | Train Loss: 0.00013885 | Val Loss: 0.00018632 | Grad Norm: 2.4701e-02 | LR: 0.080000
# Epoch  2000 | Train Loss: 0.00005458 | Val Loss: 0.00010150 | Grad Norm: 1.2646e-02 | LR: 0.064000
# Epoch  2100 | Train Loss: 0.00003342 | Val Loss: 0.00007909 | Grad Norm: 9.3973e-03 | LR: 0.064000
# Epoch  2200 | Train Loss: 0.00005149 | Val Loss: 0.00005789 | Grad Norm: 1.4110e-02 | LR: 0.064000
# Epoch  2300 | Train Loss: 0.00010020 | Val Loss: 0.00009230 | Grad Norm: 2.4643e-02 | LR: 0.064000
# Epoch  2400 | Train Loss: 0.00008304 | Val Loss: 0.00024850 | Grad Norm: 1.9960e-02 | LR: 0.064000
# Epoch  2500 | Train Loss: 0.00021153 | Val Loss: 0.00010166 | Grad Norm: 3.2786e-02 | LR: 0.064000
# Epoch  2600 | Train Loss: 0.00126636 | Val Loss: 0.00089141 | Grad Norm: 8.5160e-02 | LR: 0.064000
# Epoch  9700 | Train Loss: 0.00007908 | Val Loss: 0.00002427 | Grad Norm: 2.2196e-02 | LR: 0.013422
# Epoch  9800 | Train Loss: 0.00003622 | Val Loss: 0.00004722 | Grad Norm: 1.3483e-02 | LR: 0.013422
# Epoch  9900 | Train Loss: 0.00005273 | Val Loss: 0.00002304 | Grad Norm: 1.4831e-02 | LR: 0.013422
# Epoch 10000 | Train Loss: 0.00001590 | Val Loss: 0.00001119 | Grad Norm: 7.8683e-03 | LR: 0.010737
# Epoch 10100 | Train Loss: 0.00001012 | Val Loss: 0.00000551 | Grad Norm: 7.2018e-03 | LR: 0.010737
# Epoch 10200 | Train Loss: 0.00000774 | Val Loss: 0.00000533 | Grad Norm: 5.3441e-03 | LR: 0.010737
# Epoch 10300 | Train Loss: 0.00002826 | Val Loss: 0.00001049 | Grad Norm: 1.3018e-02 | LR: 0.010737
# Epoch 10400 | Train Loss: 0.00003750 | Val Loss: 0.00002626 | Grad Norm: 1.1615e-02 | LR: 0.010737
# Epoch 10500 | Train Loss: 0.00001189 | Val Loss: 0.00001037 | Grad Norm: 6.9575e-03 | LR: 0.010737
# Epoch 10600 | Train Loss: 0.00001955 | Val Loss: 0.00001488 | Grad Norm: 9.8950e-03 | LR: 0.010737
# Epoch 10700 | Train Loss: 0.00004188 | Val Loss: 0.00005138 | Grad Norm: 1.3279e-02 | LR: 0.010737
# Epoch 10800 | Train Loss: 0.00003104 | Val Loss: 0.00006726 | Grad Norm: 1.2176e-02 | LR: 0.010737
# Epoch 10900 | Train Loss: 0.00001387 | Val Loss: 0.00001011 | Grad Norm: 7.7027e-03 | LR: 0.010737
# Epoch 11000 | Train Loss: 0.00000657 | Val Loss: 0.00000510 | Grad Norm: 4.4159e-03 | LR: 0.008590
# Epoch 11100 | Train Loss: 0.00000558 | Val Loss: 0.00001225 | Grad Norm: 3.6374e-03 | LR: 0.008590
# Epoch 11200 | Train Loss: 0.00001267 | Val Loss: 0.00000884 | Grad Norm: 8.0537e-03 | LR: 0.008590
# Epoch 11300 | Train Loss: 0.00000808 | Val Loss: 0.00000643 | Grad Norm: 5.2398e-03 | LR: 0.008590
# Epoch 11400 | Train Loss: 0.00000912 | Val Loss: 0.00000396 | Grad Norm: 5.5339e-03 | LR: 0.008590
# Epoch 11500 | Train Loss: 0.00001269 | Val Loss: 0.00001360 | Grad Norm: 7.3971e-03 | LR: 0.008590
# Epoch 11600 | Train Loss: 0.00001661 | Val Loss: 0.00001293 | Grad Norm: 1.0156e-02 | LR: 0.008590
# Epoch 11700 | Train Loss: 0.00001564 | Val Loss: 0.00002241 | Grad Norm: 8.1441e-03 | LR: 0.008590
# Epoch 11800 | Train Loss: 0.00004463 | Val Loss: 0.00004185 | Grad Norm: 1.5663e-02 | LR: 0.008590
# Epoch 11900 | Train Loss: 0.00003272 | Val Loss: 0.00002627 | Grad Norm: 1.2847e-02 | LR: 0.008590
# Epoch 12000 | Train Loss: 0.00001348 | Val Loss: 0.00001412 | Grad Norm: 7.9841e-03 | LR: 0.006872
# Epoch 12100 | Train Loss: 0.00000303 | Val Loss: 0.00000668 | Grad Norm: 1.7342e-03 | LR: 0.006872
# Epoch 12200 | Train Loss: 0.00000473 | Val Loss: 0.00000586 | Grad Norm: 3.5395e-03 | LR: 0.006872
# Epoch 12300 | Train Loss: 0.00000343 | Val Loss: 0.00000479 | Grad Norm: 2.0093e-03 | LR: 0.006872
# Epoch 12400 | Train Loss: 0.00000480 | Val Loss: 0.00000666 | Grad Norm: 4.3262e-03 | LR: 0.006872
# Epoch 12500 | Train Loss: 0.00000568 | Val Loss: 0.00000986 | Grad Norm: 4.2526e-03 | LR: 0.006872
# Epoch 12600 | Train Loss: 0.00000811 | Val Loss: 0.00001874 | Grad Norm: 6.0741e-03 | LR: 0.006872
# Epoch 12700 | Train Loss: 0.00001624 | Val Loss: 0.00001223 | Grad Norm: 8.4660e-03 | LR: 0.006872
# Epoch 12800 | Train Loss: 0.00001310 | Val Loss: 0.00002520 | Grad Norm: 7.0562e-03 | LR: 0.006872
# Epoch 12900 | Train Loss: 0.00002656 | Val Loss: 0.00001716 | Grad Norm: 1.1374e-02 | LR: 0.006872
# Epoch 13000 | Train Loss: 0.00000709 | Val Loss: 0.00000736 | Grad Norm: 5.0437e-03 | LR: 0.005498
# Epoch 13100 | Train Loss: 0.00000443 | Val Loss: 0.00000476 | Grad Norm: 3.2510e-03 | LR: 0.005498
# Epoch 13200 | Train Loss: 0.00000336 | Val Loss: 0.00000374 | Grad Norm: 2.6980e-03 | LR: 0.005498
# Epoch 13300 | Train Loss: 0.00000326 | Val Loss: 0.00000427 | Grad Norm: 2.4788e-03 | LR: 0.005498
# Epoch 13400 | Train Loss: 0.00000452 | Val Loss: 0.00000316 | Grad Norm: 3.8911e-03 | LR: 0.005498
# Epoch 13500 | Train Loss: 0.00000838 | Val Loss: 0.00000748 | Grad Norm: 5.8675e-03 | LR: 0.005498
# Epoch 13600 | Train Loss: 0.00000505 | Val Loss: 0.00000951 | Grad Norm: 4.4678e-03 | LR: 0.005498
# Epoch 13700 | Train Loss: 0.00000450 | Val Loss: 0.00000643 | Grad Norm: 3.4078e-03 | LR: 0.005498
# Epoch 13800 | Train Loss: 0.00000823 | Val Loss: 0.00001415 | Grad Norm: 6.2568e-03 | LR: 0.005498
# Epoch 13900 | Train Loss: 0.00001223 | Val Loss: 0.00000703 | Grad Norm: 7.7001e-03 | LR: 0.005498
# Epoch 14000 | Train Loss: 0.00000419 | Val Loss: 0.00000881 | Grad Norm: 2.8125e-03 | LR: 0.004398
# Epoch 14100 | Train Loss: 0.00000463 | Val Loss: 0.00000529 | Grad Norm: 3.5762e-03 | LR: 0.004398
# Epoch 14200 | Train Loss: 0.00000516 | Val Loss: 0.00000594 | Grad Norm: 4.1408e-03 | LR: 0.004398
# Epoch 14300 | Train Loss: 0.00000599 | Val Loss: 0.00000627 | Grad Norm: 5.2294e-03 | LR: 0.004398
# Epoch 16700 | Train Loss: 0.00000234 | Val Loss: 0.00000374 | Grad Norm: 1.8073e-03 | LR: 0.002815
# Epoch 16800 | Train Loss: 0.00000559 | Val Loss: 0.00000265 | Grad Norm: 4.4696e-03 | LR: 0.002815
# Epoch 16900 | Train Loss: 0.00000377 | Val Loss: 0.00000289 | Grad Norm: 3.3952e-03 | LR: 0.002815
# Epoch 17000 | Train Loss: 0.00000287 | Val Loss: 0.00000452 | Grad Norm: 2.7650e-03 | LR: 0.002252
# Epoch 17100 | Train Loss: 0.00000270 | Val Loss: 0.00000252 | Grad Norm: 2.9918e-03 | LR: 0.002252
# Epoch 17200 | Train Loss: 0.00000401 | Val Loss: 0.00000311 | Grad Norm: 3.6705e-03 | LR: 0.002252
# Epoch 17300 | Train Loss: 0.00000256 | Val Loss: 0.00000223 | Grad Norm: 2.2585e-03 | LR: 0.002252
# Epoch 17400 | Train Loss: 0.00000221 | Val Loss: 0.00000215 | Grad Norm: 1.6458e-03 | LR: 0.002252
# Epoch 17500 | Train Loss: 0.00000213 | Val Loss: 0.00000272 | Grad Norm: 2.5105e-03 | LR: 0.002252
# Epoch 17600 | Train Loss: 0.00000272 | Val Loss: 0.00000193 | Grad Norm: 2.9682e-03 | LR: 0.002252
# Epoch 17700 | Train Loss: 0.00000415 | Val Loss: 0.00000294 | Grad Norm: 3.7818e-03 | LR: 0.002252
# Epoch 17800 | Train Loss: 0.00000304 | Val Loss: 0.00000450 | Grad Norm: 3.0647e-03 | LR: 0.002252
# Epoch 17900 | Train Loss: 0.00000568 | Val Loss: 0.00000457 | Grad Norm: 4.7412e-03 | LR: 0.002252
# Epoch 18000 | Train Loss: 0.00000286 | Val Loss: 0.00000235 | Grad Norm: 2.8145e-03 | LR: 0.001801
# Epoch 18100 | Train Loss: 0.00000271 | Val Loss: 0.00000257 | Grad Norm: 2.4533e-03 | LR: 0.001801
# Epoch 18200 | Train Loss: 0.00000201 | Val Loss: 0.00000201 | Grad Norm: 1.4733e-03 | LR: 0.001801
# Epoch 18300 | Train Loss: 0.00000224 | Val Loss: 0.00000310 | Grad Norm: 2.5433e-03 | LR: 0.001801
# Epoch 18400 | Train Loss: 0.00000208 | Val Loss: 0.00000242 | Grad Norm: 2.1954e-03 | LR: 0.001801
# Epoch 18500 | Train Loss: 0.00000221 | Val Loss: 0.00000402 | Grad Norm: 2.0174e-03 | LR: 0.001801
# Epoch 18600 | Train Loss: 0.00000215 | Val Loss: 0.00000217 | Grad Norm: 2.0350e-03 | LR: 0.001801
# Epoch 18700 | Train Loss: 0.00000352 | Val Loss: 0.00000303 | Grad Norm: 3.6798e-03 | LR: 0.001801
# Epoch 18800 | Train Loss: 0.00000239 | Val Loss: 0.00000215 | Grad Norm: 2.0731e-03 | LR: 0.001801
# Epoch 18900 | Train Loss: 0.00000159 | Val Loss: 0.00000215 | Grad Norm: 1.2904e-03 | LR: 0.001801
# Epoch 19000 | Train Loss: 0.00000317 | Val Loss: 0.00000223 | Grad Norm: 3.5144e-03 | LR: 0.001441
# Epoch 19100 | Train Loss: 0.00000223 | Val Loss: 0.00000248 | Grad Norm: 1.8674e-03 | LR: 0.001441
# Epoch 19200 | Train Loss: 0.00000296 | Val Loss: 0.00000195 | Grad Norm: 2.8423e-03 | LR: 0.001441
# Epoch 19300 | Train Loss: 0.00000191 | Val Loss: 0.00000201 | Grad Norm: 1.6036e-03 | LR: 0.001441
# Epoch 19400 | Train Loss: 0.00000213 | Val Loss: 0.00000210 | Grad Norm: 2.3499e-03 | LR: 0.001441
# Epoch 19500 | Train Loss: 0.00000164 | Val Loss: 0.00000200 | Grad Norm: 1.3999e-03 | LR: 0.001441
# Epoch 19600 | Train Loss: 0.00000284 | Val Loss: 0.00000234 | Grad Norm: 3.1350e-03 | LR: 0.001441
# Epoch 19700 | Train Loss: 0.00000188 | Val Loss: 0.00000221 | Grad Norm: 1.4669e-03 | LR: 0.001441
# Epoch 19800 | Train Loss: 0.00000261 | Val Loss: 0.00000271 | Grad Norm: 2.8626e-03 | LR: 0.001441
# Epoch 19900 | Train Loss: 0.00000229 | Val Loss: 0.00000193 | Grad Norm: 2.1806e-03 | LR: 0.001441
# Epoch 20000 | Train Loss: 0.00000267 | Val Loss: 0.00000206 | Grad Norm: 2.3958e-03 | LR: 0.001153
# Epoch 20100 | Train Loss: 0.00000207 | Val Loss: 0.00000219 | Grad Norm: 2.0577e-03 | LR: 0.001153
# Epoch 20200 | Train Loss: 0.00000195 | Val Loss: 0.00000208 | Grad Norm: 1.6323e-03 | LR: 0.001153
# Epoch 20300 | Train Loss: 0.00000174 | Val Loss: 0.00000219 | Grad Norm: 1.5452e-03 | LR: 0.001153
# Epoch 20400 | Train Loss: 0.00000180 | Val Loss: 0.00000179 | Grad Norm: 1.4736e-03 | LR: 0.001153
# Epoch 20500 | Train Loss: 0.00000172 | Val Loss: 0.00000198 | Grad Norm: 1.4776e-03 | LR: 0.001153
# Epoch 20600 | Train Loss: 0.00000144 | Val Loss: 0.00000257 | Grad Norm: 1.2184e-03 | LR: 0.001153
# Epoch 20700 | Train Loss: 0.00000211 | Val Loss: 0.00000208 | Grad Norm: 1.8933e-03 | LR: 0.001153
# Epoch 20800 | Train Loss: 0.00000164 | Val Loss: 0.00000218 | Grad Norm: 1.8246e-03 | LR: 0.001153
# Epoch 20900 | Train Loss: 0.00000180 | Val Loss: 0.00000192 | Grad Norm: 1.9243e-03 | LR: 0.001153
# Epoch 21000 | Train Loss: 0.00000192 | Val Loss: 0.00000294 | Grad Norm: 1.9660e-03 | LR: 0.000922
# Epoch 21100 | Train Loss: 0.00000216 | Val Loss: 0.00000179 | Grad Norm: 2.3389e-03 | LR: 0.000922
# Epoch 21200 | Train Loss: 0.00000210 | Val Loss: 0.00000182 | Grad Norm: 2.2163e-03 | LR: 0.000922
# Epoch 21300 | Train Loss: 0.00000132 | Val Loss: 0.00000149 | Grad Norm: 1.1166e-03 | LR: 0.000922
# Epoch 21400 | Train Loss: 0.00000247 | Val Loss: 0.00000318 | Grad Norm: 2.6233e-03 | LR: 0.000922
# Epoch 21500 | Train Loss: 0.00000211 | Val Loss: 0.00000221 | Grad Norm: 1.9117e-03 | LR: 0.000922
# Epoch 21600 | Train Loss: 0.00000162 | Val Loss: 0.00000186 | Grad Norm: 1.1733e-03 | LR: 0.000922
# Epoch 21700 | Train Loss: 0.00000203 | Val Loss: 0.00000167 | Grad Norm: 2.0258e-03 | LR: 0.000922
# Epoch 21800 | Train Loss: 0.00000152 | Val Loss: 0.00000142 | Grad Norm: 1.5086e-03 | LR: 0.000922
# Epoch 21900 | Train Loss: 0.00000177 | Val Loss: 0.00000191 | Grad Norm: 1.9843e-03 | LR: 0.000922
# Epoch 22000 | Train Loss: 0.00000144 | Val Loss: 0.00000198 | Grad Norm: 1.2974e-03 | LR: 0.000738
# Epoch 22100 | Train Loss: 0.00000134 | Val Loss: 0.00000141 | Grad Norm: 1.1235e-03 | LR: 0.000738
# Epoch 22200 | Train Loss: 0.00000149 | Val Loss: 0.00000158 | Grad Norm: 1.1480e-03 | LR: 0.000738
# Epoch 22300 | Train Loss: 0.00000148 | Val Loss: 0.00000191 | Grad Norm: 1.5017e-03 | LR: 0.000738
# Epoch 22400 | Train Loss: 0.00000166 | Val Loss: 0.00000189 | Grad Norm: 1.6577e-03 | LR: 0.000738
# Epoch 22500 | Train Loss: 0.00000148 | Val Loss: 0.00000149 | Grad Norm: 1.1146e-03 | LR: 0.000738
# Epoch 22600 | Train Loss: 0.00000163 | Val Loss: 0.00000154 | Grad Norm: 1.3961e-03 | LR: 0.000738
# Epoch 22700 | Train Loss: 0.00000133 | Val Loss: 0.00000132 | Grad Norm: 9.5059e-04 | LR: 0.000738
# Epoch 22800 | Train Loss: 0.00000187 | Val Loss: 0.00000189 | Grad Norm: 1.8327e-03 | LR: 0.000738
# Epoch 22900 | Train Loss: 0.00000142 | Val Loss: 0.00000148 | Grad Norm: 1.4497e-03 | LR: 0.000738
# Epoch 23000 | Train Loss: 0.00000156 | Val Loss: 0.00000153 | Grad Norm: 1.4639e-03 | LR: 0.000590
# Epoch 23100 | Train Loss: 0.00000134 | Val Loss: 0.00000138 | Grad Norm: 9.2503e-04 | LR: 0.000590
# Epoch 23200 | Train Loss: 0.00000153 | Val Loss: 0.00000157 | Grad Norm: 1.0976e-03 | LR: 0.000590
# Epoch 23300 | Train Loss: 0.00000140 | Val Loss: 0.00000150 | Grad Norm: 8.3974e-04 | LR: 0.000590
# Epoch 23400 | Train Loss: 0.00000247 | Val Loss: 0.00000178 | Grad Norm: 2.6542e-03 | LR: 0.000590
# Epoch 23500 | Train Loss: 0.00000118 | Val Loss: 0.00000162 | Grad Norm: 7.4493e-04 | LR: 0.000590
# Epoch 23600 | Train Loss: 0.00000141 | Val Loss: 0.00000140 | Grad Norm: 9.1194e-04 | LR: 0.000590
# Epoch 23700 | Train Loss: 0.00000132 | Val Loss: 0.00000147 | Grad Norm: 1.0321e-03 | LR: 0.000590
# Epoch 26100 | Train Loss: 0.00000100 | Val Loss: 0.00000139 | Grad Norm: 7.3854e-04 | LR: 0.000302
# Epoch 26200 | Train Loss: 0.00000112 | Val Loss: 0.00000140 | Grad Norm: 7.5181e-04 | LR: 0.000302
# Epoch 26300 | Train Loss: 0.00000146 | Val Loss: 0.00000138 | Grad Norm: 1.6105e-03 | LR: 0.000302
# Epoch 26400 | Train Loss: 0.00000122 | Val Loss: 0.00000133 | Grad Norm: 8.5117e-04 | LR: 0.000302
# Epoch 26500 | Train Loss: 0.00000165 | Val Loss: 0.00000164 | Grad Norm: 1.6789e-03 | LR: 0.000302
# Epoch 26600 | Train Loss: 0.00000128 | Val Loss: 0.00000133 | Grad Norm: 1.0079e-03 | LR: 0.000302
# Epoch 26700 | Train Loss: 0.00000130 | Val Loss: 0.00000132 | Grad Norm: 1.1604e-03 | LR: 0.000302
# Epoch 26800 | Train Loss: 0.00000137 | Val Loss: 0.00000154 | Grad Norm: 8.3498e-04 | LR: 0.000302
# Epoch 26900 | Train Loss: 0.00000122 | Val Loss: 0.00000127 | Grad Norm: 6.2986e-04 | LR: 0.000302
# Epoch 27000 | Train Loss: 0.00000136 | Val Loss: 0.00000129 | Grad Norm: 1.3886e-03 | LR: 0.000242
# Epoch 27100 | Train Loss: 0.00000124 | Val Loss: 0.00000118 | Grad Norm: 7.1403e-04 | LR: 0.000242
# Epoch 27200 | Train Loss: 0.00000118 | Val Loss: 0.00000122 | Grad Norm: 6.7695e-04 | LR: 0.000242
# Epoch 27300 | Train Loss: 0.00000126 | Val Loss: 0.00000131 | Grad Norm: 8.7027e-04 | LR: 0.000242
# Epoch 27400 | Train Loss: 0.00000120 | Val Loss: 0.00000123 | Grad Norm: 7.6951e-04 | LR: 0.000242
# Epoch 27500 | Train Loss: 0.00000152 | Val Loss: 0.00000133 | Grad Norm: 1.3614e-03 | LR: 0.000242
# Epoch 27600 | Train Loss: 0.00000120 | Val Loss: 0.00000122 | Grad Norm: 9.1537e-04 | LR: 0.000242
# Epoch 27700 | Train Loss: 0.00000116 | Val Loss: 0.00000127 | Grad Norm: 8.6966e-04 | LR: 0.000242
# Epoch 27800 | Train Loss: 0.00000108 | Val Loss: 0.00000147 | Grad Norm: 1.0522e-03 | LR: 0.000242
# Epoch 27900 | Train Loss: 0.00000147 | Val Loss: 0.00000133 | Grad Norm: 9.1471e-04 | LR: 0.000242
# Epoch 28000 | Train Loss: 0.00000135 | Val Loss: 0.00000153 | Grad Norm: 1.3896e-03 | LR: 0.000193
# Epoch 28100 | Train Loss: 0.00000087 | Val Loss: 0.00000118 | Grad Norm: 5.7165e-04 | LR: 0.000193
# Epoch 28200 | Train Loss: 0.00000119 | Val Loss: 0.00000159 | Grad Norm: 7.7247e-04 | LR: 0.000193
# Epoch 28300 | Train Loss: 0.00000096 | Val Loss: 0.00000130 | Grad Norm: 7.8661e-04 | LR: 0.000193
# Epoch 28400 | Train Loss: 0.00000127 | Val Loss: 0.00000135 | Grad Norm: 9.0516e-04 | LR: 0.000193
# Epoch 28500 | Train Loss: 0.00000123 | Val Loss: 0.00000126 | Grad Norm: 9.8558e-04 | LR: 0.000193
# Epoch 28600 | Train Loss: 0.00000125 | Val Loss: 0.00000129 | Grad Norm: 1.2256e-03 | LR: 0.000193
# Epoch 28700 | Train Loss: 0.00000116 | Val Loss: 0.00000121 | Grad Norm: 5.9506e-04 | LR: 0.000193
# Epoch 28800 | Train Loss: 0.00000135 | Val Loss: 0.00000127 | Grad Norm: 1.1853e-03 | LR: 0.000193
# Epoch 28900 | Train Loss: 0.00000123 | Val Loss: 0.00000130 | Grad Norm: 9.4227e-04 | LR: 0.000193
# Epoch 29000 | Train Loss: 0.00000101 | Val Loss: 0.00000122 | Grad Norm: 5.1163e-04 | LR: 0.000155
# Epoch 29100 | Train Loss: 0.00000118 | Val Loss: 0.00000120 | Grad Norm: 7.1225e-04 | LR: 0.000155
# Epoch 29200 | Train Loss: 0.00000104 | Val Loss: 0.00000136 | Grad Norm: 7.6196e-04 | LR: 0.000155
# Epoch 29300 | Train Loss: 0.00000136 | Val Loss: 0.00000122 | Grad Norm: 1.1542e-03 | LR: 0.000155
# Epoch 29400 | Train Loss: 0.00000111 | Val Loss: 0.00000126 | Grad Norm: 3.1286e-04 | LR: 0.000155
# Epoch 29500 | Train Loss: 0.00000129 | Val Loss: 0.00000125 | Grad Norm: 8.4945e-04 | LR: 0.000155
# Epoch 29600 | Train Loss: 0.00000130 | Val Loss: 0.00000127 | Grad Norm: 6.6016e-04 | LR: 0.000155
# Epoch 29700 | Train Loss: 0.00000113 | Val Loss: 0.00000127 | Grad Norm: 8.3438e-04 | LR: 0.000155
# Epoch 29800 | Train Loss: 0.00000102 | Val Loss: 0.00000118 | Grad Norm: 5.9654e-04 | LR: 0.000155
# Epoch 29900 | Train Loss: 0.00000108 | Val Loss: 0.00000118 | Grad Norm: 5.6404e-04 | LR: 0.000155
# Epoch 29999 | Train Loss: 0.00000124 | Val Loss: 0.00000116 | Grad Norm: 5.7878e-04 | LR: 0.000155

# %% [markdown]
# ### Latent Qubit Z Expectation Value

# %%
@qml.qnode(dev, interface="jax")
def latent_qubit_z(params, x):
    # Prepare reference state
    qml.RX(x[0], wires=latent_wire)
    qml.RX(x[1], wires=trash_wire)

    # Encode data
    # Encode data
    expressive_block(
        x=x,
        weights=params,
        wires=[latent_wire, trash_wire],
        rot=[qml.RY, qml.RZ, qml.RX],
        reupload=True,
        alternate_embedding=True
    )

    z = qml.expval(qml.PauliZ(latent_wire))
    return z

# %% [markdown]
# ### Full AutoEncoder Circuit (With Reconstruction)

# %%
@qml.qnode(dev, interface="jax")
def recon_points(params, x):
    # Prepare reference state
    qml.RX(x[0], wires=latent_wire)
    qml.RX(x[1], wires=trash_wire)

    # Encode data
    # Encode data
    expressive_block(
        x=x,
        weights=params,
        wires=[latent_wire, trash_wire],
        rot=[qml.RY, qml.RZ, qml.RX],
        reupload=True,
        alternate_embedding=True
    )

    # Reset trash qubit using SWAP from reference
    qml.SWAP(wires=[trash_wire, reference_wire])   

    # Decode data
    # Encode data
    expressive_block_adjoint(
        x=x,
        weights=params,
        wires=[latent_wire, trash_wire],
        rot=[qml.RY, qml.RZ, qml.RX],
        reupload=True,
        alternate_embedding=True
    )

    z0 = qml.expval(qml.PauliZ(latent_wire))
    z1 = qml.expval(qml.PauliZ(trash_wire))
    return z0 ,z1

# %% [markdown]
# ## Testing the Model

# %% [markdown]
# ### Test Data

# %%
test_data, true_angles = generate_circle_dataset(n_samples=1000, seed=1)

# %% [markdown]
# ### Output Qubits & Latent Qubit Measurement

# %%
# Latent Z
z_expectations = jax.vmap(lambda x: latent_qubit_z(params, x))(test_data)

# %%
# Output Z (Z=cosx)
z_expectations_out = jax.vmap(lambda x: recon_points(params, x))(test_data)
# Stack the outputs to shape (N, 2)
z_expectations_out_stacked = jnp.stack(z_expectations_out, axis=-1)  # from (2, N) → (N, 2)

# %%
# Reconstructed points [arccos(z)=x_recon]
recon = jnp.arccos(z_expectations_out_stacked)

# %% [markdown]
# ### Graphs

# %% [markdown]
# #### Latent Qubit Measurement Graphs

# %%
# Sort by angle for nicer plotting
sorted_idx = jnp.argsort(true_angles)
sorted_angles = true_angles[sorted_idx]
sorted_zs = z_expectations[sorted_idx]

plt.figure(figsize=(8, 4))
plt.plot(sorted_angles, sorted_zs, label='⟨Z⟩ of latent qubit')
plt.xlabel("True angle (radians)")
plt.ylabel("⟨Z⟩ expectation")
plt.title("Latent qubit ⟨Z⟩ vs. True input angle")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Reconstruction Plot

# %%
plt.figure(figsize=(7, 7))
plt.scatter(test_data[:, 0], test_data[:, 1], s=8, alpha=0.5, label='Original', edgecolor='k')
plt.scatter(recon[:, 0], recon[:, 1], s=8, alpha=0.5, label='Reconstruction', marker='x', color='crimson')
plt.legend(fontsize=12)
plt.title("Original vs Reconstruction (S¹)", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.axis('equal')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Testing with Gaussian Noise (mild anomaly) / Roustness test

# %%
# Gaussian Noise (mild anomaly) / Roustness test
def generate_noisy_circle(n_samples=300, seed=42, noise_std=0.17):
    data, angles = generate_circle_dataset(n_samples, seed)
    key = jax.random.PRNGKey(seed)
    noise = noise_std * jax.random.normal(key, shape=data.shape)
    noisy_data = data + noise
    return noisy_data, angles

# %%
# Data
noisy_data, true_angles = generate_noisy_circle(n_samples=500, seed=1)
# Latent Z
z_expectations_n = jax.vmap(lambda x: latent_qubit_z(params, x))(noisy_data)
# Output Z (Z=cosx)
z_expectations_out_n = jax.vmap(lambda x: recon_points(params, x))(noisy_data)
# Stack the outputs to shape (N, 2)
z_expectations_out_stacked_n = jnp.stack(z_expectations_out_n, axis=-1)  # from (2, N) → (N, 2)
# Reconstructed points [arccos(z)=x_recon]
recon_n = jnp.arccos(z_expectations_out_stacked_n)

# %%
# Sort by angle for nicer plotting
sorted_idx = jnp.argsort(true_angles)
sorted_angles_n = true_angles[sorted_idx]
sorted_zs_n = z_expectations_n[sorted_idx]

plt.figure(figsize=(8, 4))
plt.plot(sorted_angles_n, sorted_zs_n, label='⟨Z⟩ of latent qubit')
plt.xlabel("True angle (radians)")
plt.ylabel("⟨Z⟩ expectation")
plt.title("Latent qubit ⟨Z⟩ vs. True input angle")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))
plt.scatter(noisy_data[:, 0], noisy_data[:, 1], s=8, alpha=0.5, label='Original', edgecolor='k')
plt.scatter(recon_n[:, 0], recon_n[:, 1], s=8, alpha=0.5, label='Reconstruction', marker='x', color='crimson')
plt.legend(fontsize=12)
plt.title("Original vs Reconstruction (S¹)", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.axis('equal')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Testing with artificial gaps

# %%
def generate_circle_with_gap(n_samples=300, seed=42, gap_range=(jnp.pi/3, jnp.pi/2)):
    key = jax.random.PRNGKey(seed)
    # Sample until enough valid points are outside the gap
    valid_angles = []
    while len(valid_angles) < n_samples:
        angles = jax.random.uniform(key, shape=(n_samples,), minval=0, maxval=2*jnp.pi)
        filtered = angles[(angles < gap_range[0]) | (angles > gap_range[1])]
        valid_angles.extend(filtered.tolist())
        key, _ = jax.random.split(key)

    angles = jnp.array(valid_angles[:n_samples])
    data = jnp.stack([jnp.cos(angles)+1+ds, jnp.sin(angles)+1+ds], axis=1)
    return data, angles

# %%
# Data
gap_data, true_angles = generate_circle_with_gap(n_samples=500, seed=1)
# Latent Z
z_expectations_g = jax.vmap(lambda x: latent_qubit_z(params, x))(gap_data)
# Output Z (Z=cosx)
z_expectations_out_g = jax.vmap(lambda x: recon_points(params, x))(gap_data)
# Stack the outputs to shape (N, 2)
z_expectations_out_stacked_g = jnp.stack(z_expectations_out_g, axis=-1)  # from (2, N) → (N, 2)
# Reconstructed points [arccos(z)=x_recon]
recon_g = jnp.arccos(z_expectations_out_stacked_g)

# %%
# Sort by angle for nicer plotting
sorted_idx = jnp.argsort(true_angles)
sorted_angles_g = true_angles[sorted_idx]
sorted_zs_g = z_expectations_g[sorted_idx]

plt.figure(figsize=(8, 4))
plt.plot(sorted_angles_g, sorted_zs_g, label='⟨Z⟩ of latent qubit')
plt.axvline(x=jnp.pi / 3, color='red', linestyle='dotted', label=r'$x = \frac{\pi}{3}$')
plt.axvline(x=jnp.pi / 2, color='red', linestyle='dotted', label=r'$x = \frac{\pi}{2}$')
plt.xlabel("True angle (radians)")
plt.ylabel("⟨Z⟩ expectation")
plt.title("Latent qubit ⟨Z⟩ vs. True input angle")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))
plt.scatter(gap_data[:, 0], gap_data[:, 1], s=8, alpha=0.5, label='Original', edgecolor='k')
plt.scatter(recon_g[:, 0], recon_g[:, 1], s=8, alpha=0.5, label='Reconstruction', marker='x', color='crimson')
plt.legend(fontsize=12)
plt.title("Original vs Reconstruction (S¹)", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.axis('equal')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Testing for data corruption (injected outliers / spikes off the circle)

# %%
def generate_circle_with_outliers(n_samples=300, seed=42, outlier_fraction=0.1):
    data, angles = generate_circle_dataset(n_samples, seed)
    n_outliers = int(n_samples * outlier_fraction)

    key = jax.random.PRNGKey(seed)
    outlier_points = jax.random.uniform(key, shape=(n_outliers, 2), minval=2.5, maxval=3)

    # Replace random entries with outliers
    indices = np.random.choice(n_samples, n_outliers, replace=False)
    data = data.at[indices].set(outlier_points)

    return data, angles

# %%
# Data
spike_data, true_angles = generate_circle_with_outliers(n_samples=500, seed=1)
# Latent Z
z_expectations_s = jax.vmap(lambda x: latent_qubit_z(params, x))(spike_data)
# Output Z (Z=cosx)
z_expectations_out_s = jax.vmap(lambda x: recon_points(params, x))(spike_data)
# Stack the outputs to shape (N, 2)
z_expectations_out_stacked_s = jnp.stack(z_expectations_out_s, axis=-1)  # from (2, N) → (N, 2)
# Reconstructed points [arccos(z)=x_recon]
recon_s = jnp.arccos(z_expectations_out_stacked_s)

# %%
# Sort by angle for nicer plotting
sorted_idx = jnp.argsort(true_angles)
sorted_angles_s = true_angles[sorted_idx]
sorted_zs_s = z_expectations_s[sorted_idx]

plt.figure(figsize=(8, 4))
plt.plot(sorted_angles_s, sorted_zs_s, label='⟨Z⟩ of latent qubit')
plt.xlabel("True angle (radians)")
plt.ylabel("⟨Z⟩ expectation")
plt.title("Latent qubit ⟨Z⟩ vs. True input angle")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))
plt.scatter(spike_data[:, 0], spike_data[:, 1], s=8, alpha=0.5, label='Original', edgecolor='k')
plt.scatter(recon_s[:, 0], recon_s[:, 1], s=8, alpha=0.5, label='Reconstruction', marker='x', color='crimson')
plt.legend(fontsize=12)
plt.title("Original vs Reconstruction (S¹)", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.axis('equal')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Testing systematic deviations (anomalous radius)

# %%
def generate_off_circle(n_samples=300, seed=42, radius_shift=0.3):
    key = jax.random.PRNGKey(seed)
    angles = jax.random.uniform(key, shape=(n_samples,), minval=0, maxval=2*jnp.pi)
    r = 1.0 + radius_shift
    data = jnp.stack([r * jnp.cos(angles) + 1 + ds, r * jnp.sin(angles) + 1 + ds], axis=1)
    return data, angles

# %%
# Data
rad_data, true_angles = generate_off_circle(n_samples=500, seed=1)
# Latent Z
z_expectations_r = jax.vmap(lambda x: latent_qubit_z(params, x))(rad_data)
# Output Z (Z=cosx)
z_expectations_out_r = jax.vmap(lambda x: recon_points(params, x))(rad_data)
# Stack the outputs to shape (N, 2)
z_expectations_out_stacked_r = jnp.stack(z_expectations_out_r, axis=-1)  # from (2, N) → (N, 2)
# Reconstructed points [arccos(z)=x_recon]
recon_r = jnp.arccos(z_expectations_out_stacked_r)

# %%
# Sort by angle for nicer plotting
sorted_idx = jnp.argsort(true_angles)
sorted_angles_r = true_angles[sorted_idx]
sorted_zs_r = z_expectations_r[sorted_idx]

plt.figure(figsize=(8, 4))
plt.plot(sorted_angles_r, sorted_zs_r, label='⟨Z⟩ of latent qubit')
plt.xlabel("True angle (radians)")
plt.ylabel("⟨Z⟩ expectation")
plt.title("Latent qubit ⟨Z⟩ vs. True input angle")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 7))
plt.scatter(rad_data[:, 0], rad_data[:, 1], s=8, alpha=0.5, label='Original', edgecolor='k')
plt.scatter(recon_r[:, 0], recon_r[:, 1], s=8, alpha=0.5, label='Reconstruction', marker='x', color='crimson')
plt.legend(fontsize=12)
plt.title("Original vs Reconstruction (S¹)", fontsize=14)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.axis('equal')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
